# %% [markdown]
# <a href="https://colab.research.google.com/github/claudiotancredi/mlinapptests/blob/main/Stage_2_transfer_learning_RNGN12_on_RNGN19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-eb12f433-7023-8ff3-6c00-f336c93f5221)

# %% [markdown]
# ### Clone GitHub repo

# %%
# !git clone https://github.com/claudiotancredi/Machine-learning-in-applications
# Out:
# Cloning into 'mlinapptests'...
# remote: Enumerating objects: 852, done.
# remote: Counting objects: 100% (268/268), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 852 (delta 156), reused 214 (delta 124), pack-reused 584
# Receiving objects: 100% (852/852), 209.05 MiB | 12.27 MiB/s, done.
# Resolving deltas: 100% (409/409), done.
# Checking out files: 100% (201/201), done.

# %% [markdown]
# ### Initialization

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import tensorflow as tf
import glob
import sys
import random
import datetime
import PIL

# %% [markdown]
# ### Mount Drive
# It is supposed to include a "2022-DC03" path with "images.zip" of ALL the images.
# THIS NOTEBOOK NEEDS TO BE RUN AFTER THE STAGE1 MRCNN.

# %%
# Mount the Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Directory to save logs and trained model
tool = "RNGN19"      # This is the second component, the new one we want to finetune
MODEL_DIR = os.path.join("/content/drive/MyDrive/2022-DC03/stage2", "logs")
TRAIN_DIR = os.path.join("/content/drive/MyDrive/2022-DC03/stage2/dataset_s1mrcnn_"+tool, "train")
TEST_DIR = os.path.join("/content/drive/MyDrive/2022-DC03/stage2/dataset_s1mrcnn_"+tool, "test")

# %% [markdown]
# ### Visualize data

# %%
image_count_train = len(list(glob.glob(TRAIN_DIR + '/*/*.jpg')))
image_count_test = len(list(glob.glob(TEST_DIR + '/*/*.jpg')))
print("Number of images for train and validation: ", image_count_train)
print("Number of images for test: ", image_count_test)
# Out:
# Number of images for train and validation:  182
# Number of images for test:  47

# %%
SRC_DIR = os.path.abspath("/content/mlinapptests/src/models/Stage2_ResNet50")

sys.path.append(SRC_DIR)

from utils import visualize_n_random_samples

visualize_n_random_samples(TRAIN_DIR, 8)
visualize_n_random_samples(TEST_DIR, 5)

# %%
batch_size = 4
img_height = 120
img_width = 120
# resize is automatically performed

# %% [markdown]
# # Generalization test - Evaluation from RNGN12 to RNGN19
# No training, just evaluation.

# %%
data_augmentation = tf.keras.Sequential(
    [tf.keras.layers.RandomFlip("horizontal_and_vertical"), tf.keras.layers.RandomRotation(0.25)]
)

base_model = tf.keras.applications.ResNet50(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(img_height, img_width, 3),
    include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
SRC_DIR = os.path.abspath("/content/mlinapptests/src/models/Stage2_ResNet50")

sys.path.append(SRC_DIR)

from model import net 

model = net(base_model, data_augmentation, img_height, img_width)

# %%
# Load back already trained on first component type weights
base_model_path = '/content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN12_STAGE2_RESNET50_20220714T2315/resnet50_tool_wear.h5'    # This is the model on which the resnet was already trained
model.load_weights(base_model_path)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  TEST_DIR,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  shuffle=False)
# Out:
# Found 47 files belonging to 3 classes.

# %%
import json

dataset_ok = test_ds.unbatch().filter(lambda image, label: label == 2).batch(4)
dataset_nok = test_ds.unbatch().filter(lambda image, label: label == 1).batch(4)
dataset_doubt = test_ds.unbatch().filter(lambda image, label: label == 0).batch(4)
count_ok = len(list(dataset_ok.unbatch().enumerate(start=0).as_numpy_iterator()))
count_nok = len(list(dataset_nok.unbatch().enumerate(start=0).as_numpy_iterator()))
count_doubt = len(list(dataset_doubt.unbatch().enumerate(start=0).as_numpy_iterator()))
print("Total number of images in test set (only images not already predicted by stage 1): ", count_nok+count_ok+count_doubt)
print("Number of NOK images in test set (only images not already predicted by stage 1): ", count_nok)
print("Number of DOUBT images in test set (only images not already predicted by stage 1): ", count_doubt)
print("Number of OK images in test set (only images not already predicted by stage 1): ", count_ok)

JSON_PATH = "/content/drive/MyDrive/2022-DC03/stage2/output_s1mrcnn_testset_" + tool + ".json"

count_images_stage1_ok = 0
count_images_stage1_nok = 0
count_images_stage1_doubt = 0
data = ''
with open(JSON_PATH, "r") as f:
  data = json.load(f)
for element in data:
    if len(element["bbox"])==0:
        if "wo" in element["name"]:
          count_images_stage1_ok+=1
        elif "wd" in element["name"]:
          count_images_stage1_doubt+=1
        else:
          count_images_stage1_nok+=1
print("\nTotal number of images in test set already predicted by stage 1: ", count_images_stage1_nok+count_images_stage1_doubt+count_images_stage1_ok)
print("Number of NOK images in test set already predicted by stage 1: ", count_images_stage1_nok)
print("Number of DOUBT images in test set already predicted by stage 1: ", count_images_stage1_doubt)
print("Number of OK images in test set already predicted by stage 1: ", count_images_stage1_ok)

total_ts = count_images_stage1_doubt+count_images_stage1_nok+count_images_stage1_ok+count_ok+count_nok+count_doubt
print("\nTotal number of images in test set: ", total_ts)
# Out:
# Total number of images in test set (only images not already predicted by stage 1):  47
# Number of NOK images in test set (only images not already predicted by stage 1):  6
# Number of DOUBT images in test set (only images not already predicted by stage 1):  5
# Number of OK images in test set (only images not already predicted by stage 1):  36
#
# Total number of images in test set already predicted by stage 1:  0
# Number of NOK images in test set already predicted by stage 1:  0
# Number of DOUBT images in test set already predicted by stage 1:  0
# Number of OK images in test set already predicted by stage 1:  0
#
# Total number of images in test set:  47

# %%
SRC_DIR = os.path.abspath("/content/mlinapptests/src/models/Stage2_ResNet50")

sys.path.append(SRC_DIR)
from utils import predict_stats
import json

print("Evaluate on test data")

data = ''
with open(JSON_PATH, "r") as f:
  data = json.load(f)

#results = model.evaluate(test_ds)
#print("test loss, test acc:", results)

counter_ok, counter_doubt, counter_nok, counter_crit, counter_semicrit \
    = predict_stats(model, test_ds, data)

print("\nAccuracy: ", (counter_ok+counter_doubt+counter_nok)/total_ts)

print("\nOK accuracy: ", counter_ok/(count_ok+count_images_stage1_ok))
print("NOK accuracy: ", counter_nok/(count_nok+count_images_stage1_nok))
print("DOUBT accuracy: ", counter_doubt/(count_doubt+count_images_stage1_doubt))

print("\nNumber of critical wrong predictions (gt is wn, prediction is wo): ", counter_crit)
print("Number of semi-critical wrong predictions (gt is wn, prediction is wd): ", counter_semicrit)
# Out:
# Evaluate on test data
# Ground truth was:  DOUBT  but prediction is:  OK
# Ground truth was:  DOUBT  but prediction is:  NOK
# Ground truth was:  DOUBT  but prediction is:  NOK
# Ground truth was:  DOUBT  but prediction is:  NOK
# Ground truth was:  NOK  but prediction is:  OK
# Ground truth was:  NOK  but prediction is:  OK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  DOUBT
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  NOK
#
# Accuracy:  0.5106382978723404
#
# OK accuracy:  0.5277777777777778
# NOK accuracy:  0.6666666666666666
# DOUBT accuracy:  0.2
#
# Number of critical wrong predictions (gt is wn, prediction is wo):  2
# Number of semi-critical wrong predictions (gt is wn, prediction is wd):  0

# %%
from utils import display_bbox, get_prediction_info
import json

ORIGINAL_IMAGES_PATH = "/content/drive/MyDrive/2022-DC03/Stage1_Mask_RCNN/images/test/"
JSON_PATH = "/content/drive/MyDrive/2022-DC03/stage2/output_s1mrcnn_testset_" + tool + ".json"

data = ''
with open(JSON_PATH, "r") as f:
  data = json.load(f)

test_ds_ok = test_ds.unbatch().filter(lambda image, label: label == 2).batch(4)
test_ds_nok = test_ds.unbatch().filter(lambda image, label: label == 1).batch(4)
test_ds_doubt = test_ds.unbatch().filter(lambda image, label: label == 0).batch(4)
ok_paths = []
[ok_paths.append(path) for path in test_ds.file_paths if "wo" in path]
nok_paths = []
[nok_paths.append(path) for path in test_ds.file_paths if "wn" in path]
doubt_paths = []
[doubt_paths.append(path) for path in test_ds.file_paths if "wd" in path]


# Get and visualize NOK test predictions
images_arr, predictions_arr, bbox_arr, names \
    = get_prediction_info(model, test_ds_nok, test_ds, nok_paths, ORIGINAL_IMAGES_PATH, data, n=10)
display_bbox(images_arr, predictions_arr, bbox_arr, names)

# %%
#Visualize predictions of stage 1 if any
import json
from utils import get_prediction_s1_info

ORIGINAL_IMAGES_PATH = "/content/drive/MyDrive/2022-DC03/Stage1_Mask_RCNN/images/test/"
JSON_PATH = "/content/drive/MyDrive/2022-DC03/stage2/output_s1mrcnn_testset_" + tool + ".json"

data = ''
with open(JSON_PATH, "r") as f:
  data = json.load(f)

images_arr, predictions_arr, names= get_prediction_s1_info(ORIGINAL_IMAGES_PATH, data)

display_bbox(images_arr, predictions_arr, None, names)

# %% [markdown]
# # Stage2 finetuning

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  TRAIN_DIR,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 178 files belonging to 3 classes.
# Using 143 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  TRAIN_DIR,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 178 files belonging to 3 classes.
# Using 35 files for validation.

# %%
SRC_DIR = os.path.abspath("/content/mlinapptests/src/models/Stage2_ResNet50")

sys.path.append(SRC_DIR)

from utils import display

class_names = train_ds.class_names
print(class_names)
images_arr = []
labels_arr = []
for element in train_ds.take(8):
  images_arr.append(element[0][0].numpy())
  labels_arr.append("GT: " + class_names[element[1][0].numpy()])
display(images_arr, labels_arr)
# Out:
# ['DOUBT', 'NOK', 'OK']

# %% [markdown]
# ### Model

# %%
log_dir = os.path.join(MODEL_DIR, "{}{}{}{}{:%Y%m%dT%H%M}".format(
                "tool_wear","_",tool,"_STAGE2_RESNET50_TRANSFER_LEARNING_", datetime.datetime.now()))
tb_log_dir = os.path.join("/content/drive/MyDrive/2022-DC03/stage2/tblogs", tool+"_STAGE2_RESNET50_TRANSFER_LEARNING_"+datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
checkpoint_path = os.path.join(log_dir, "resnet50_tool_wear.h5")

# Callbacks
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path, verbose=1, save_weights_only=True, save_best_only=True)
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1, restore_best_weights=True)
tb_callback = tf.keras.callbacks.TensorBoard(tb_log_dir, update_freq="epoch")

# %%
data_augmentation = tf.keras.Sequential(
    [tf.keras.layers.RandomFlip("horizontal_and_vertical"), tf.keras.layers.RandomRotation(0.25)]
)

base_model = tf.keras.applications.ResNet50(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(img_height, img_width, 3),
    include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
SRC_DIR = os.path.abspath("/content/mlinapptests/src/models/Stage2_ResNet50")

sys.path.append(SRC_DIR)

from utils import visualize_after_data_augm

visualize_after_data_augm(train_ds, data_augmentation)

# %%
base_model.trainable = True

# %%
SRC_DIR = os.path.abspath("/content/mlinapptests/src/models/Stage2_ResNet50")

sys.path.append(SRC_DIR)

from model import net 

model = net(base_model, data_augmentation, img_height, img_width)

# %%
# Load back already trained on first component type weights
base_model_path = '/content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN12_STAGE2_RESNET50_20220714T2315/resnet50_tool_wear.h5'    # This is the model on which the resnet was already trained
model.load_weights(base_model_path)

# %%
base_model.trainable = False

# %%
# %load_ext tensorboard

# %%
import shutil
import glob

if os.path.exists("/content/drive/MyDrive/2022-DC03/stage2/tblogs"):
  for match in glob.glob("/content/drive/MyDrive/2022-DC03/stage2/tblogs/*"):
    shutil.rmtree(match)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 120, 3)]     0
#
#  sequential (Sequential)     (None, 120, 120, 3)       0
#
#  tf.__operators__.getitem (S  (None, 120, 120, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 120, 120, 3)      0
#
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 3)                 6147
#
# =================================================================
# Total params: 23,593,859
# Trainable params: 6,147
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

# %%
if not os.path.exists(log_dir):
    os.makedirs(log_dir)
history = model.fit(train_ds, epochs=100,  validation_data=val_ds, callbacks=[tb_callback, es_callback, cp_callback])
# Out:
# Epoch 1/100
# 36/36 [==============================] - ETA: 0s - loss: 1.7496 - sparse_categorical_accuracy: 0.5734
# Epoch 1: val_loss improved from inf to 0.71901, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 24s 345ms/step - loss: 1.7496 - sparse_categorical_accuracy: 0.5734 - val_loss: 0.7190 - val_sparse_categorical_accuracy: 0.7714
# Epoch 2/100
# 33/36 [==========================>...] - ETA: 0s - loss: 1.0739 - sparse_categorical_accuracy: 0.7197
# Epoch 2: val_loss improved from 0.71901 to 0.58047, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 1s 37ms/step - loss: 1.0894 - sparse_categorical_accuracy: 0.7133 - val_loss: 0.5805 - val_sparse_categorical_accuracy: 0.7714
# Epoch 3/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.9101 - sparse_categorical_accuracy: 0.7500
# Epoch 3: val_loss improved from 0.58047 to 0.44173, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 1s 40ms/step - loss: 0.8913 - sparse_categorical_accuracy: 0.7552 - val_loss: 0.4417 - val_sparse_categorical_accuracy: 0.8286
# Epoch 4/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.8274 - sparse_categorical_accuracy: 0.7714
# Epoch 4: val_loss improved from 0.44173 to 0.34989, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 43ms/step - loss: 0.8105 - sparse_categorical_accuracy: 0.7762 - val_loss: 0.3499 - val_sparse_categorical_accuracy: 0.8286
# Epoch 5/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.6102 - sparse_categorical_accuracy: 0.8071
# Epoch 5: val_loss improved from 0.34989 to 0.33030, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 46ms/step - loss: 0.5976 - sparse_categorical_accuracy: 0.8112 - val_loss: 0.3303 - val_sparse_categorical_accuracy: 0.8571
# Epoch 6/100
# 36/36 [==============================] - ETA: 0s - loss: 0.4051 - sparse_categorical_accuracy: 0.8601
# Epoch 6: val_loss did not improve from 0.33030
# 36/36 [==============================] - 1s 23ms/step - loss: 0.4051 - sparse_categorical_accuracy: 0.8601 - val_loss: 0.3832 - val_sparse_categorical_accuracy: 0.8286
# Epoch 7/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.4315 - sparse_categorical_accuracy: 0.8529
# Epoch 7: val_loss improved from 0.33030 to 0.32474, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 48ms/step - loss: 0.4200 - sparse_categorical_accuracy: 0.8531 - val_loss: 0.3247 - val_sparse_categorical_accuracy: 0.8286
# Epoch 8/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.4496 - sparse_categorical_accuracy: 0.8603
# Epoch 8: val_loss improved from 0.32474 to 0.25663, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 48ms/step - loss: 0.4481 - sparse_categorical_accuracy: 0.8601 - val_loss: 0.2566 - val_sparse_categorical_accuracy: 0.8571
# Epoch 9/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.4246 - sparse_categorical_accuracy: 0.8500
# Epoch 9: val_loss did not improve from 0.25663
# 36/36 [==============================] - 1s 24ms/step - loss: 0.4165 - sparse_categorical_accuracy: 0.8531 - val_loss: 0.2731 - val_sparse_categorical_accuracy: 0.8857
# Epoch 10/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.2300 - sparse_categorical_accuracy: 0.9265
# Epoch 10: val_loss did not improve from 0.25663
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2281 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.3148 - val_sparse_categorical_accuracy: 0.8286
# Epoch 11/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.3764 - sparse_categorical_accuracy: 0.8429
# Epoch 11: val_loss did not improve from 0.25663
# 36/36 [==============================] - 1s 25ms/step - loss: 0.3773 - sparse_categorical_accuracy: 0.8392 - val_loss: 0.3068 - val_sparse_categorical_accuracy: 0.8000
# Epoch 12/100
# 36/36 [==============================] - ETA: 0s - loss: 0.3172 - sparse_categorical_accuracy: 0.8671
# Epoch 12: val_loss did not improve from 0.25663
# 36/36 [==============================] - 1s 25ms/step - loss: 0.3172 - sparse_categorical_accuracy: 0.8671 - val_loss: 0.3658 - val_sparse_categorical_accuracy: 0.9143
# Epoch 13/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.2079 - sparse_categorical_accuracy: 0.8971
# Epoch 13: val_loss improved from 0.25663 to 0.24979, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 50ms/step - loss: 0.1995 - sparse_categorical_accuracy: 0.9021 - val_loss: 0.2498 - val_sparse_categorical_accuracy: 0.8857
# Epoch 14/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.2944 - sparse_categorical_accuracy: 0.9000
# Epoch 14: val_loss improved from 0.24979 to 0.23681, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 50ms/step - loss: 0.2933 - sparse_categorical_accuracy: 0.9021 - val_loss: 0.2368 - val_sparse_categorical_accuracy: 0.8857
# Epoch 15/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.2693 - sparse_categorical_accuracy: 0.9265
# Epoch 15: val_loss did not improve from 0.23681
# 36/36 [==============================] - 1s 26ms/step - loss: 0.2566 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.2493 - val_sparse_categorical_accuracy: 0.8857
# Epoch 16/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1983 - sparse_categorical_accuracy: 0.9412
# Epoch 16: val_loss did not improve from 0.23681
# 36/36 [==============================] - 1s 25ms/step - loss: 0.1978 - sparse_categorical_accuracy: 0.9371 - val_loss: 0.2773 - val_sparse_categorical_accuracy: 0.8571
# Epoch 17/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.2181 - sparse_categorical_accuracy: 0.9265
# Epoch 17: val_loss improved from 0.23681 to 0.23286, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 50ms/step - loss: 0.2116 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.2329 - val_sparse_categorical_accuracy: 0.9143
# Epoch 18/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.2407 - sparse_categorical_accuracy: 0.8897
# Epoch 18: val_loss improved from 0.23286 to 0.23112, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 50ms/step - loss: 0.2383 - sparse_categorical_accuracy: 0.8881 - val_loss: 0.2311 - val_sparse_categorical_accuracy: 0.8571
# Epoch 19/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1695 - sparse_categorical_accuracy: 0.9044
# Epoch 19: val_loss improved from 0.23112 to 0.21409, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 51ms/step - loss: 0.1685 - sparse_categorical_accuracy: 0.9091 - val_loss: 0.2141 - val_sparse_categorical_accuracy: 0.8857
# Epoch 20/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1124 - sparse_categorical_accuracy: 0.9580
# Epoch 20: val_loss did not improve from 0.21409
# 36/36 [==============================] - 1s 27ms/step - loss: 0.1124 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.3057 - val_sparse_categorical_accuracy: 0.8571
# Epoch 21/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1821 - sparse_categorical_accuracy: 0.9371
# Epoch 21: val_loss improved from 0.21409 to 0.20966, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 54ms/step - loss: 0.1821 - sparse_categorical_accuracy: 0.9371 - val_loss: 0.2097 - val_sparse_categorical_accuracy: 0.8857
# Epoch 22/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1516 - sparse_categorical_accuracy: 0.9371
# Epoch 22: val_loss did not improve from 0.20966
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1516 - sparse_categorical_accuracy: 0.9371 - val_loss: 0.2399 - val_sparse_categorical_accuracy: 0.8857
# Epoch 23/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1291 - sparse_categorical_accuracy: 0.9559
# Epoch 23: val_loss did not improve from 0.20966
# 36/36 [==============================] - 1s 27ms/step - loss: 0.1419 - sparse_categorical_accuracy: 0.9441 - val_loss: 0.2695 - val_sparse_categorical_accuracy: 0.8857
# Epoch 24/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1792 - sparse_categorical_accuracy: 0.9412
# Epoch 24: val_loss improved from 0.20966 to 0.17945, saving model to /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5
# 36/36 [==============================] - 2s 54ms/step - loss: 0.1710 - sparse_categorical_accuracy: 0.9441 - val_loss: 0.1794 - val_sparse_categorical_accuracy: 0.8857
# Epoch 25/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1306 - sparse_categorical_accuracy: 0.9706
# Epoch 25: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 30ms/step - loss: 0.1283 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.2081 - val_sparse_categorical_accuracy: 0.8571
# Epoch 26/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1824 - sparse_categorical_accuracy: 0.9301
# Epoch 26: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 30ms/step - loss: 0.1824 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.1965 - val_sparse_categorical_accuracy: 0.8857
# Epoch 27/100
# 36/36 [==============================] - ETA: 0s - loss: 0.0713 - sparse_categorical_accuracy: 0.9860
# Epoch 27: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 30ms/step - loss: 0.0713 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.2129 - val_sparse_categorical_accuracy: 0.8571
# Epoch 28/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1354 - sparse_categorical_accuracy: 0.9632
# Epoch 28: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 27ms/step - loss: 0.1401 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.1985 - val_sparse_categorical_accuracy: 0.8571
# Epoch 29/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.1295 - sparse_categorical_accuracy: 0.9643
# Epoch 29: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 27ms/step - loss: 0.1270 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.2011 - val_sparse_categorical_accuracy: 0.9143
# Epoch 30/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1314 - sparse_categorical_accuracy: 0.9441
# Epoch 30: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 29ms/step - loss: 0.1314 - sparse_categorical_accuracy: 0.9441 - val_loss: 0.2242 - val_sparse_categorical_accuracy: 0.8571
# Epoch 31/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1417 - sparse_categorical_accuracy: 0.9580
# Epoch 31: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 28ms/step - loss: 0.1417 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.2227 - val_sparse_categorical_accuracy: 0.9143
# Epoch 32/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1149 - sparse_categorical_accuracy: 0.9706
# Epoch 32: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1126 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.2492 - val_sparse_categorical_accuracy: 0.9143
# Epoch 33/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1135 - sparse_categorical_accuracy: 0.9632
# Epoch 33: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1126 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.2038 - val_sparse_categorical_accuracy: 0.8857
# Epoch 34/100
# 35/36 [============================>.] - ETA: 0s - loss: 0.1523 - sparse_categorical_accuracy: 0.9786
# Epoch 34: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 27ms/step - loss: 0.1548 - sparse_categorical_accuracy: 0.9790 - val_loss: 0.2120 - val_sparse_categorical_accuracy: 0.8571
# Epoch 35/100
# 36/36 [==============================] - ETA: 0s - loss: 0.1105 - sparse_categorical_accuracy: 0.9860
# Epoch 35: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 29ms/step - loss: 0.1105 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.2300 - val_sparse_categorical_accuracy: 0.8857
# Epoch 36/100
# 36/36 [==============================] - ETA: 0s - loss: 0.0777 - sparse_categorical_accuracy: 0.9720
# Epoch 36: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0777 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.2420 - val_sparse_categorical_accuracy: 0.9143
# Epoch 37/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1946 - sparse_categorical_accuracy: 0.9265
# Epoch 37: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1962 - sparse_categorical_accuracy: 0.9231 - val_loss: 0.2485 - val_sparse_categorical_accuracy: 0.8857
# Epoch 38/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.0587 - sparse_categorical_accuracy: 1.0000
# Epoch 38: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 27ms/step - loss: 0.0628 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.2735 - val_sparse_categorical_accuracy: 0.8857
# Epoch 39/100
# 36/36 [==============================] - ETA: 0s - loss: 0.0861 - sparse_categorical_accuracy: 0.9720
# Epoch 39: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 26ms/step - loss: 0.0861 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.2419 - val_sparse_categorical_accuracy: 0.8857
# Epoch 40/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1015 - sparse_categorical_accuracy: 0.9559
# Epoch 40: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1000 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.3094 - val_sparse_categorical_accuracy: 0.8857
# Epoch 41/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1537 - sparse_categorical_accuracy: 0.9559
# Epoch 41: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1501 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.1951 - val_sparse_categorical_accuracy: 0.9143
# Epoch 42/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.0987 - sparse_categorical_accuracy: 0.9706
# Epoch 42: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1026 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.2387 - val_sparse_categorical_accuracy: 0.8857
# Epoch 43/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1104 - sparse_categorical_accuracy: 0.9632
# Epoch 43: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 26ms/step - loss: 0.1051 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.2465 - val_sparse_categorical_accuracy: 0.8571
# Epoch 44/100
# 34/36 [===========================>..] - ETA: 0s - loss: 0.1012 - sparse_categorical_accuracy: 0.9706Restoring model weights from the end of the best epoch: 24.
#
# Epoch 44: val_loss did not improve from 0.17945
# 36/36 [==============================] - 1s 31ms/step - loss: 0.1036 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.1918 - val_sparse_categorical_accuracy: 0.9143
# Epoch 44: early stopping

# %%
SRC_DIR = os.path.abspath("/content/mlinapptests/src/models/Stage2_ResNet50")

sys.path.append(SRC_DIR)

from utils import plot_history

plot_history(history)

# %%
SRC_DIR = os.path.abspath("/content/mlinapptests/src/models/Stage2_ResNet50")

sys.path.append(SRC_DIR)

from utils import find_last

# Load back weights
model.load_weights(find_last(MODEL_DIR, tool))
# Out:
# /content/drive/MyDrive/2022-DC03/stage2/logs/tool_wear_RNGN19_STAGE2_RESNET50_TRANSFER_LEARNING_20220716T2027/resnet50_tool_wear.h5

# %%
print("Evaluate on validation data")
results = model.evaluate(val_ds)
print("validation loss, validation acc:", results)
# Out:
# Evaluate on validation data
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1794 - sparse_categorical_accuracy: 0.8857
# validation loss, validation acc: [0.17944973707199097, 0.8857142925262451]

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  TEST_DIR,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size,
  shuffle=False)
# Out:
# Found 47 files belonging to 3 classes.

# %%
import json

dataset_ok = test_ds.unbatch().filter(lambda image, label: label == 2).batch(4)
dataset_nok = test_ds.unbatch().filter(lambda image, label: label == 1).batch(4)
dataset_doubt = test_ds.unbatch().filter(lambda image, label: label == 0).batch(4)
count_ok = len(list(dataset_ok.unbatch().enumerate(start=0).as_numpy_iterator()))
count_nok = len(list(dataset_nok.unbatch().enumerate(start=0).as_numpy_iterator()))
count_doubt = len(list(dataset_doubt.unbatch().enumerate(start=0).as_numpy_iterator()))
print("Total number of images in test set (only images not already predicted by stage 1): ", count_nok+count_ok+count_doubt)
print("Number of NOK images in test set (only images not already predicted by stage 1): ", count_nok)
print("Number of DOUBT images in test set (only images not already predicted by stage 1): ", count_doubt)
print("Number of OK images in test set (only images not already predicted by stage 1): ", count_ok)

JSON_PATH = "/content/drive/MyDrive/2022-DC03/stage2/output_s1mrcnn_testset_" + tool + ".json"

count_images_stage1_ok = 0
count_images_stage1_nok = 0
count_images_stage1_doubt = 0
data = ''
with open(JSON_PATH, "r") as f:
  data = json.load(f)
for element in data:
    if len(element["bbox"])==0:
        if "wo" in element["name"]:
          count_images_stage1_ok+=1
        elif "wd" in element["name"]:
          count_images_stage1_doubt+=1
        else:
          count_images_stage1_nok+=1
print("\nTotal number of images in test set already predicted by stage 1: ", count_images_stage1_nok+count_images_stage1_doubt+count_images_stage1_ok)
print("Number of NOK images in test set already predicted by stage 1: ", count_images_stage1_nok)
print("Number of DOUBT images in test set already predicted by stage 1: ", count_images_stage1_doubt)
print("Number of OK images in test set already predicted by stage 1: ", count_images_stage1_ok)

total_ts = count_images_stage1_doubt+count_images_stage1_nok+count_images_stage1_ok+count_ok+count_nok+count_doubt
print("\nTotal number of images in test set: ", total_ts)
# Out:
# Total number of images in test set (only images not already predicted by stage 1):  47
# Number of NOK images in test set (only images not already predicted by stage 1):  6
# Number of DOUBT images in test set (only images not already predicted by stage 1):  5
# Number of OK images in test set (only images not already predicted by stage 1):  36
#
# Total number of images in test set already predicted by stage 1:  0
# Number of NOK images in test set already predicted by stage 1:  0
# Number of DOUBT images in test set already predicted by stage 1:  0
# Number of OK images in test set already predicted by stage 1:  0
#
# Total number of images in test set:  47

# %%
SRC_DIR = os.path.abspath("/content/mlinapptests/src/models/Stage2_ResNet50")

sys.path.append(SRC_DIR)
from utils import predict_stats
import json

print("Evaluate on test data")

data = ''
with open(JSON_PATH, "r") as f:
  data = json.load(f)

#results = model.evaluate(test_ds)
#print("test loss, test acc:", results)

counter_ok, counter_doubt, counter_nok, counter_crit, counter_semicrit \
    = predict_stats(model, test_ds, data)

print("\nAccuracy: ", (counter_ok+counter_doubt+counter_nok)/total_ts)

print("\nOK accuracy: ", counter_ok/(count_ok+count_images_stage1_ok))
print("NOK accuracy: ", counter_nok/(count_nok+count_images_stage1_nok))
print("DOUBT accuracy: ", counter_doubt/(count_doubt+count_images_stage1_doubt))

print("\nNumber of critical wrong predictions (gt is wn, prediction is wo): ", counter_crit)
print("Number of semi-critical wrong predictions (gt is wn, prediction is wd): ", counter_semicrit)
# Out:
# Evaluate on test data
# Ground truth was:  DOUBT  but prediction is:  OK
# Ground truth was:  NOK  but prediction is:  OK
# Ground truth was:  NOK  but prediction is:  OK
# Ground truth was:  OK  but prediction is:  DOUBT
# Ground truth was:  OK  but prediction is:  NOK
# Ground truth was:  OK  but prediction is:  DOUBT
#
# Accuracy:  0.8723404255319149
#
# OK accuracy:  0.9166666666666666
# NOK accuracy:  0.6666666666666666
# DOUBT accuracy:  0.8
#
# Number of critical wrong predictions (gt is wn, prediction is wo):  2
# Number of semi-critical wrong predictions (gt is wn, prediction is wd):  0

# %%
from utils import display_bbox, get_prediction_info
import json

ORIGINAL_IMAGES_PATH = "/content/drive/MyDrive/2022-DC03/Stage1_Mask_RCNN/images/test/"
JSON_PATH = "/content/drive/MyDrive/2022-DC03/stage2/output_s1mrcnn_testset_" + tool + ".json"

data = ''
with open(JSON_PATH, "r") as f:
  data = json.load(f)

test_ds_ok = test_ds.unbatch().filter(lambda image, label: label == 2).batch(4)
test_ds_nok = test_ds.unbatch().filter(lambda image, label: label == 1).batch(4)
test_ds_doubt = test_ds.unbatch().filter(lambda image, label: label == 0).batch(4)
ok_paths = []
[ok_paths.append(path) for path in test_ds.file_paths if "wo" in path]
nok_paths = []
[nok_paths.append(path) for path in test_ds.file_paths if "wn" in path]
doubt_paths = []
[doubt_paths.append(path) for path in test_ds.file_paths if "wd" in path]


# Get and visualize NOK test predictions
images_arr, predictions_arr, bbox_arr, names \
    = get_prediction_info(model, test_ds_nok, test_ds, nok_paths, ORIGINAL_IMAGES_PATH, data, n=10)
display_bbox(images_arr, predictions_arr, bbox_arr, names)

# %%
#Visualize predictions of stage 1 if any
import json
from utils import get_prediction_s1_info

ORIGINAL_IMAGES_PATH = "/content/drive/MyDrive/2022-DC03/Stage1_Mask_RCNN/images/test/"
JSON_PATH = "/content/drive/MyDrive/2022-DC03/stage2/output_s1mrcnn_testset_" + tool + ".json"

data = ''
with open(JSON_PATH, "r") as f:
  data = json.load(f)

images_arr, predictions_arr, names= get_prediction_s1_info(ORIGINAL_IMAGES_PATH, data)

display_bbox(images_arr, predictions_arr, None, names)
